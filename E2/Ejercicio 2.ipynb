# %% [markdown]
# ## Ejercicio 2
#
# ### Nombre: Pablo Enrique Miranda Aránguiz
# ### Fecha: 27/10/2021
#
# ### Instrucciones
# A cada alumno se le asignó en el ejercicio 1 un conjunto de datos en formato CSV
#
# Deberá:
#
# 1. Crear una carpeta nueva en su repositorio git con el nombre E2 (0.2 pto)
# 2. Dentro de E2 crear una carpeta que se llame datos. (0,2 pto)
# 3. Guardar los datos asignados en esa carpeta. (0,2 pto)
# 4. Dentro de E2 debera crear un Jupyter Notebook llamado E2. (0,2 pto)
# 5. En el Jupyter Notebook, configurar la primera casilla en Lenguaje Markdown y escribir su nombre, fecha, y esta lista de instrucciones de forma ordenada. (0,2 puntos)
# 6. Importar la librería pandasde python para poder procesar y graficar los datos del archivo. Utilizar describe, shapee indicar para que se utilicen estos comandos y que puede deducir de esta información. Debe separar el código en las casillas que estime conveniente, pero se solicita minimo que en una casilla esten solo las importaciones, en otra solo la lectura de los datos y otra con los plots, además de cada casilla debe tener una casilla previa que describa el código en formato markdown. (3 puntos)
# 7. Hacer los gráficos correspondientes al conjunto de datos seleccionado. (1 ptos)
# 8. Utilizar los comandos adecuados de git para actualizar su repositorio y dejarlo disponible en github de forma pública. (1 ptos)
#
# La nota será calculada de la siguiente manera:
#
# NOTA FINAL = Puntaje + 1
#
# ⚠️Bonus Track, pueden usar la librería seabornpara embellecer sus gráficos de matplotlib. (0,5 puntos)

# %% [markdown]
# ### Cormobilidades: Ejercicio 2
#
# Procesarlo con csv y crear los siguientes gráficos:
#
# 1. Graficar comorbilidades en el tiempo para hospitalizados y no hospitalizados
# 2. Como los datos están acumulados, deberá calcular la comorbilidad para cada día y graficar eso en el tiempo.

# %%
import numpy as np
from scipy import stats
import pandas as pd
import csv
from matplotlib import pyplot as plt

# %% [markdown]
# ## Primer paso:
#
# Importamos todas las librerías necesarias para la realización de nuestro ejercicio.

# %%
Cormobilidad = pd.read_csv('data/Comorbilidad.csv')

# %% [markdown]
# ## Segundo Paso:
#
# Ya importado pandas abrimos nuestro archivo Csv donde veremos la visualización de el mismo con todos sus datos tanto en filas como columnas.

# %%
Cormobilidad
# Out:
#                       Comorbilidad Hospitalización  2020-05-25  2020-05-29  \
# 0            Hipertensión arterial              NO      6350.0      8134.0
# 1                         Diabetes              NO      2770.0      3569.0
# 2                         Obesidad              NO      1351.0      1743.0
# 3                             Asma              NO      1554.0      1909.0
# 4        Enfermedad cardiovascular              NO       540.0       664.0
# 5      Enfermedad pulmonar crónica              NO       405.0       415.0
# 6              Cardiopatía crónica              NO       405.0       498.0
# 7         Enfermedad renal crónica              NO       203.0       332.0
# 8   Enfermedad neurológica crónica              NO       203.0       249.0
# 9               Inmunocomprometido              NO        68.0        83.0
# 10     Enfermedad hepática crónica              NO        68.0        83.0
# ...

# %% [markdown]
# ### Visualización del archivo Csv llamado con pandas

# %%
Cormobilidad.dtypes
# Out:
# Comorbilidad        object
# Hospitalización     object
# 2020-05-25         float64
# 2020-05-29         float64
# 2020-06-01         float64
#                     ...
# 2021-08-23         float64
# 2021-08-27         float64
# 2021-08-30         float64
# 2021-09-03         float64
# 2021-09-06         float64
# Length: 135, dtype: object

# %% [markdown]
# ## Dtypes
#
# Esta librería nos sirve para ver que datos o en que cadena de caracteres se encuentran cada uno de nuestros datos tanto en filas como columnas de nuestro archivo Csv.

# %%
Cormobilidad.describe()
# Out:
#         2020-05-25   2020-05-29   2020-06-01    2020-06-05    2020-06-08  \
# count    22.000000    22.000000    22.000000     22.000000     22.000000
# mean    873.454545  1083.454545  1289.545455   1511.954545   1748.909091
# std    1411.463871  1807.117297  2166.554885   2568.975588   3010.330814
# min      68.000000    83.000000    96.000000    112.000000    127.000000
# 25%     203.000000   249.750000   290.000000    338.000000    382.000000
# 50%     318.500000   355.500000   399.500000    459.000000    509.000000
# 75%    1081.500000  1266.250000  1463.750000   1675.000000   1898.250000
# max    6350.000000  8134.000000  9725.000000  11543.000000  13491.000000
#
#          2020-06-12    2020-06-15    2020-06-19    2020-06-23    2020-06-28  \
# count     22.000000     22.000000     22.000000     22.000000     22.000000
# mean    2062.000000   2328.772727   3032.136364   3366.181818   3729.090909
# std     3586.030582   4090.963397   5521.731710   6158.805246   6862.900927
# ...

# %% [markdown]
# ## Describe ()
#
# Es una función de pandas que se utiliza para encontrar datos estadísticos dentro de un DataFrame, mas simple dentro de nuestro mismo Csv.

# %%
Cormobilidad.dtypes
# Out:
# Comorbilidad        object
# Hospitalización     object
# 2020-05-25         float64
# 2020-05-29         float64
# 2020-06-01         float64
#                     ...
# 2021-08-23         float64
# 2021-08-27         float64
# 2021-08-30         float64
# 2021-09-03         float64
# 2021-09-06         float64
# Length: 135, dtype: object

# %%
print (Cormobilidad['Hospitalización'])
# Out:
# 0     NO
# 1     NO
# 2     NO
# 3     NO
# 4     NO
# 5     NO
# 6     NO
# 7     NO
# 8     NO
# 9     NO
# 10    NO
# 11    SI
# 12    SI
# 13    SI
# 14    SI
# 15    SI
# 16    SI
# 17    SI
# 18    SI
# 19    SI
# 20    SI
# 21    SI
# Name: Hospitalización, dtype: object

# %% [markdown]
# ### Visualización de datos

# %%
Cormobilidad['Comorbilidad']
# Out:
# 0              Hipertensión arterial
# 1                           Diabetes
# 2                           Obesidad
# 3                               Asma
# 4          Enfermedad cardiovascular
# 5        Enfermedad pulmonar crónica
# 6                Cardiopatía crónica
# 7           Enfermedad renal crónica
# 8     Enfermedad neurológica crónica
# 9                 Inmunocomprometido
# 10       Enfermedad hepática crónica
# 11             Hipertensión arterial
# 12                          Diabetes
# 13                          Obesidad
# 14                              Asma
# 15         Enfermedad cardiovascular
# 16       Enfermedad pulmonar crónica
# 17               Cardiopatía crónica
# 18          Enfermedad renal crónica
# 19    Enfermedad neurológica crónica
# 20                Inmunocomprometido
# 21       Enfermedad hepática crónica
# Name: Comorbilidad, dtype: object

# %% [markdown]
# ### Visualización de datos

# %%
no = Cormobilidad[Cormobilidad['Hospitalización']=='NO']

# %% [markdown]
# ## Tercer paso
#
# En este paso es donde definimos nuestro archivo y buscamos que es lo que realmente necesitamos de el, como en mi caso solo necesitaba tomar los datos de los “NO” hospitalizados como primera etapa, se crea una línea de comandos que me permitiera ver una mejor visualización del archivo, donde solo tomara los datos que realmente necesito para que luego pueda realizar de una manera mas exacta el grafico que se debe hacer.

# %%
no
# Out:
#                       Comorbilidad Hospitalización  2020-05-25  2020-05-29  \
# 0            Hipertensión arterial              NO      6350.0      8134.0
# 1                         Diabetes              NO      2770.0      3569.0
# 2                         Obesidad              NO      1351.0      1743.0
# 3                             Asma              NO      1554.0      1909.0
# 4        Enfermedad cardiovascular              NO       540.0       664.0
# 5      Enfermedad pulmonar crónica              NO       405.0       415.0
# 6              Cardiopatía crónica              NO       405.0       498.0
# 7         Enfermedad renal crónica              NO       203.0       332.0
# 8   Enfermedad neurológica crónica              NO       203.0       249.0
# 9               Inmunocomprometido              NO        68.0        83.0
# 10     Enfermedad hepática crónica              NO        68.0        83.0
#
# ...

# %% [markdown]
# ### Al llamar a "NO" nos damos cuenta que solo esta tomando los datos necesarios para la realización de nuestro gráfico.

# %%
no.drop("Hospitalización", axis=1, inplace=True)
# Out:
# C:\Users\pablo\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ## Cuarto paso
#
# Utilizamos Drop para devolver una copia del mismo archivo donde se haya eliminado ya la columna o fila que le hemos indicado, en este caso seria nuestro "NO".

# %%
no
# Out:
#                       Comorbilidad  2020-05-25  2020-05-29  2020-06-01  \
# 0            Hipertensión arterial      6350.0      8134.0      9725.0
# 1                         Diabetes      2770.0      3569.0      4333.0
# 2                         Obesidad      1351.0      1743.0      2118.0
# 3                             Asma      1554.0      1909.0      2311.0
# 4        Enfermedad cardiovascular       540.0       664.0       770.0
# 5      Enfermedad pulmonar crónica       405.0       415.0       578.0
# 6              Cardiopatía crónica       405.0       498.0       578.0
# 7         Enfermedad renal crónica       203.0       332.0       385.0
# 8   Enfermedad neurológica crónica       203.0       249.0       289.0
# 9               Inmunocomprometido        68.0        83.0        96.0
# 10     Enfermedad hepática crónica        68.0        83.0        96.0
#
#     2020-06-05  2020-06-08  2020-06-12  2020-06-15  2020-06-19  2020-06-23  \
# ...

# %% [markdown]
# ### Vizualización de fila o columna eliminada.

# %%
no.set_index('Comorbilidad',inplace=True)

# %% [markdown]
# ## Quinto paso
#
# Fijamos una columna de cormobilidad como índice, descartando el índice existente para que luego pueda tomar nuestro dato requerido.

# %%
no.head()
# Out:
#                            2020-05-25  2020-05-29  2020-06-01  2020-06-05  \
# Comorbilidad
# Hipertensión arterial          6350.0      8134.0      9725.0     11543.0
# Diabetes                       2770.0      3569.0      4333.0      5043.0
# Obesidad                       1351.0      1743.0      2118.0      2578.0
# Asma                           1554.0      1909.0      2311.0      2690.0
# Enfermedad cardiovascular       540.0       664.0       770.0       784.0
#
#                            2020-06-08  2020-06-12  2020-06-15  2020-06-19  \
# Comorbilidad
# Hipertensión arterial         13491.0       16083       18328       24774
# Diabetes                       5982.0        7024        8015       10780
# Obesidad                       3055.0        3639        4199        5789
# Asma                           3055.0        3582        4010        5392
# Enfermedad cardiovascular       891.0        1041        1134        1500
#
# ...

# %% [markdown]
# ### Visualización del incide devuelto destacando que ya no se encuentra la columna que no requeríamos.

# %%
no.T.plot(figsize=(50,10), kind='bar')
plt.title("Pacientes con Covid que NO fueron hospitalizados por Cormobilidades", fontsize=40)
plt.xlabel("Fechas y días", fontsize=40)
plt.ylabel("Cantidad de pacientes", fontsize=40)
# Out:
# Text(0, 0.5, 'Cantidad de pacientes')

# %% [markdown]
# ## Sexto Paso:
#
# Ya importada nuestra librería plot, procedemos a crear el grafico que se requiere donde nos mostrara la cantidad de personas que "NO" fueron hospitalizadas que padecían de alguna  comorbilidad.

# %%
si = Cormobilidad[Cormobilidad['Hospitalización']=='SI']

# %% [markdown]
# ## Septimo paso:
#
# En este paso es donde definimos nuestro archivo y buscamos que es lo que realmente necesitamos de el, como en mi caso solo necesitaba tomar los datos de los “SI” hospitalizados como segunda etapa, se crea una línea de comandos que me permitiera ver una mejor visualización del archivo, donde solo tomara los datos que realmente necesito para que luego pueda realizar de una manera mas exacta el grafico que se debe hacer.

# %%
si
# Out:
#                       Comorbilidad Hospitalización  2020-05-25  2020-05-29  \
# 11           Hipertensión arterial              SI      1861.0      2192.0
# 12                        Diabetes              SI      1262.0      1467.0
# 13                        Obesidad              SI       380.0       466.0
# 14                            Asma              SI       232.0       252.0
# 15       Enfermedad cardiovascular              SI       296.0       328.0
# 16     Enfermedad pulmonar crónica              SI       309.0       344.0
# 17             Cardiopatía crónica              SI       328.0       367.0
# 18        Enfermedad renal crónica              SI       283.0       336.0
# 19  Enfermedad neurológica crónica              SI       193.0       214.0
# 20              Inmunocomprometido              SI        84.0        99.0
# 21     Enfermedad hepática crónica              SI        71.0        92.0
#
# ...

# %% [markdown]
# ### Al llamar a "SI" nos damos cuenta que solo esta tomando los datos necesarios para la realización de nuestro gráfico.

# %%
si.drop("Hospitalización", axis=1, inplace=True)
# Out:
# C:\Users\pablo\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ## Octavo paso
#
# Utilizamos Drop para devolver una copia del mismo archivo donde se haya eliminado ya la columna o fila que le hemos indicado, en este caso seria nuestro "SI".

# %%
si
# Out:
#                       Comorbilidad  2020-05-25  2020-05-29  2020-06-01  \
# 11           Hipertensión arterial      1861.0      2192.0      2556.0
# 12                        Diabetes      1262.0      1467.0      1695.0
# 13                        Obesidad       380.0       466.0       541.0
# 14                            Asma       232.0       252.0       293.0
# 15       Enfermedad cardiovascular       296.0       328.0       373.0
# 16     Enfermedad pulmonar crónica       309.0       344.0       391.0
# 17             Cardiopatía crónica       328.0       367.0       408.0
# 18        Enfermedad renal crónica       283.0       336.0       382.0
# 19  Enfermedad neurológica crónica       193.0       214.0       240.0
# 20              Inmunocomprometido        84.0        99.0       106.0
# 21     Enfermedad hepática crónica        71.0        92.0       106.0
#
#     2020-06-05  2020-06-08  2020-06-12  2020-06-15  2020-06-19  2020-06-23  \
# ...

# %% [markdown]
# ### Vizualización de fila o columna eliminada.

# %%
si.set_index('Comorbilidad',inplace=True)

# %% [markdown]
# ## Noveno paso
#
# Fijamos una columna de cormobilidad como índice, descartando el índice existente para que luego pueda tomar nuestro dato requerido.

# %%
si.head()
# Out:
#                            2020-05-25  2020-05-29  2020-06-01  2020-06-05  \
# Comorbilidad
# Hipertensión arterial          1861.0      2192.0      2556.0      3025.0
# Diabetes                       1262.0      1467.0      1695.0      1972.0
# Obesidad                        380.0       466.0       541.0       647.0
# Asma                            232.0       252.0       293.0       344.0
# Enfermedad cardiovascular       296.0       328.0       373.0       417.0
#
#                            2020-06-08  2020-06-12  2020-06-15  2020-06-19  \
# Comorbilidad
# Hipertensión arterial          3461.0        4147        4641        5302
# Diabetes                       2234.0        2615        2935        3353
# Obesidad                        729.0         858         989        1150
# Asma                            382.0         594         645         548
# Enfermedad cardiovascular       463.0         580         643         708
#
# ...

# %% [markdown]
# ### Visualización del incide devuelto destacando que ya no se encuentra la columna que no requeríamos.

# %%
si.T.plot(figsize=(50,10), kind='bar')
plt.title("Pacientes con Covid que SI fueron hospitalizados por Cormobilidades", fontsize=40)
plt.xlabel("Fechas y días", fontsize=40)
plt.ylabel("Cantidad de pacientes", fontsize=40)
# Out:
# Text(0, 0.5, 'Cantidad de pacientes')

# %% [markdown]
# ## Decimo Paso:
#
# Ya importada nuestra librería plot, procedemos a crear el grafico que se requiere donde nos mostrara la cantidad de personas que "SI" fueron hospitalizadas que padecían de alguna  comorbilidad.
